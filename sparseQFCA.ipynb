# %% [markdown]
# # importing the example model and the sparseQFCA module

# %%
include("sparseQFCA.jl")
using .sparseQFCA, SparseArrays, DelimitedFiles
S = sparse(readdlm("S.csv", header = false))
@assert typeof(S) == SparseMatrixCSC{Float64,Int64}
rev = readdlm("rev.csv", header = false)[:, 1] .== 1
@assert typeof(rev) == BitArray{1}

# %% [markdown]
# # finding all the flux coupling relations among the reactions

# %%
certificates, blocked, fctable = @time QFCA(S, rev)
println("The answer is $(all(readdlm("fctable.csv", header = false) .== fctable) ? "correct" : "wrong").")
# Out:
#  11.068522 seconds (30.19 M allocations: 1.453 GiB, 5.55% gc time)
# The answer is correct.

# %% [markdown]
# # exporting and visualizing the results

# %%
writedlm("certificates.txt", certificates)
writedlm("blocked.txt", 1*blocked)
using Colors
palette = distinguishable_colors(5)
map(x -> palette[convert(Int64, x+1)], fctable)
# Out:
# 95×95 Array{RGB{N0f8},2} with eltype RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,0.384)  …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)    …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)    …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  ⋮                         ⋱
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)    …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)    …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)       RGB{N0f8}(1.0,1.0,0.384)
